# %% [markdown]
# <a href="https://colab.research.google.com/github/herikZ13/Crawler/blob/main/CrawNoticia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalar Librerias

# %%
# !pip install bs_ds           # bs_ds (Beautiful Soup Data Science)
# !pip install fake_useragent  # fake_useragent se utiliza para generar encabezados de agente de usuario falsos (user agents) de manera aleatoria.
# !pip install lxml            # lxml es una biblioteca de procesamiento de XML y HTML.
# Out:
# Requirement already satisfied: bs_ds in /usr/local/lib/python3.10/dist-packages (0.3.12)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from bs_ds) (8.1.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bs_ds) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bs_ds) (2.0.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from bs_ds) (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bs_ds) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from bs_ds) (1.2.2)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.10/dist-packages (from bs_ds) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bs_ds) (1.11.4)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from bs_ds) (2.0.3)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from bs_ds) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->bs_ds) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bs_ds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bs_ds) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bs_ds) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bs_ds) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bs_ds) (3.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->bs_ds) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->bs_ds) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->bs_ds) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->bs_ds) (1.16.0)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 229, in _get_updated_criteria
#     for requirement in self._p.get_dependencies(candidate=candidate):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/provider.py", line 244, in get_dependencies
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/provider.py", line 244, in <listcomp>
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 391, in iter_dependencies
#     for r in self.dist.iter_dependencies():
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/pkg_resources.py", line 216, in iter_dependencies
#     return self._dist.requires(extras)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2821, in requires
#     dm = self._dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3110, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3120, in _compute_dependencies
#     reqs.extend(parse_requirements(req))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3173, in __init__
#     super(Requirement, self).__init__(requirement_string)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/requirements.py", line 102, in __init__
#     req = REQUIREMENT.parseString(requirement_string)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 1131, in parse_string
#     loc, tokens = self._parse(instring, 0)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 817, in _parseNoCache
#     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 3886, in parseImpl
#     loc, exprtokens = e._parse(instring, loc, doActions)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 817, in _parseNoCache
#     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 4114, in parseImpl
#     return e._parse(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 817, in _parseNoCache
#     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 3864, in parseImpl
#     loc, resultlist = self.exprs[0]._parse(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 817, in _parseNoCache
#     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 3888, in parseImpl
#     resultlist += exprtokens
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/results.py", line 436, in __iadd__
#     otherdictitems = [
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/results.py", line 437, in <listcomp>
#     (k, _ParseResultsWithOffset(v[0], addoffset(v[1])))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/results.py", line 17, in __getitem__
#     def __getitem__(self, i):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 206, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.10/logging/__init__.py", line 1514, in critical
#     def critical(self, msg, *args, **kwargs):
# KeyboardInterrupt
# ^C
# Requirement already satisfied: fake_useragent in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)

# %% [markdown]
# #Librerias a utilizar

# %%
# BeautifulSoup: Analiza HTML/XML para extraer datos.
from bs4 import BeautifulSoup
# requests: Realiza solicitudes HTTP para obtener contenido web.
import requests
# urljoin: Construye URLs completas a partir de enlaces.
from urllib.parse import urljoin
# se utiliza para guardar el archivo final en google drive
from google.colab import drive
drive.mount('/content/drive')
# libreria necesaria para crear un archivo CSV
import csv
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Realizar solicitud HTTP

# %%
# URL a la que se accederá
url = 'https://www.informador.mx/seccion/ultimas-noticias'

# Envía una solicitud HTTP con tiempo de espera de 3 segundos
response = requests.get(url, timeout=3)

# Imprime el código de estado de la respuesta
print('Código de estado HTTP: ', response.status_code)

# Condicional que indica una conexión exitosa (200 OK) si no imprime un mensaje en consecuencia
if response.status_code == 200:
    print(f"{'--'*20}\n\tConexión exitosa OK.\n{'--'*20}\n")
else:
    print('Error.\n\n')

# Imprime el contenido de la respuesta de la solicitud
print(f"{'***'*20}\n\tRespuesta de la solicitud:\n{'***'*20}")

# Informacion de los encabezados de la respuesta HTTP recibida del servidor.
for k, v in response.headers.items():
    print(f"{k:{30}}: {v:{40}}")
# Out:
# Código de estado HTTP:  200
# ----------------------------------------
# 	Conexión exitosa OK.
# ----------------------------------------
#
# ************************************************************
# 	Respuesta de la solicitud:
# ************************************************************
# Content-Type                  : text/html;charset=UTF-8
# Transfer-Encoding             : chunked
# Connection                    : keep-alive
# Date                          : Sun, 12 May 2024 18:20:42 GMT
# Access-Control-Allow-Origin   : *
# Last-Modified                 : Sun, 12 May 2024 18:20:42 GMT
# Content-Encoding              : gzip
# X-Cacheable                   : YES
# Cache-Control                 : max-age=300, public, stale-if-error=84600, stale-while-revalidate=120
# X-Cacheable-TTL               : 60s
# Cache-tag                     : html
# X-Cache-Hits                  : 0
# Accept-Ranges                 : bytes
# Vary                          : Accept-Encoding
# X-Cache                       : Miss from cloudfront
# Via                           : 1.1 b2b31f2fa31ca6a5c4d91e1d115c1e9c.cloudfront.net (CloudFront)
# X-Amz-Cf-Pop                  : ORD56-P2
# Alt-Svc                       : h3=":443"; ma=86400
# X-Amz-Cf-Id                   : 1nfaPBy5Jc-QEiwzfRPpr6K7HTHivLL2BDxlBYr6-7qOULpLuC3u8w==
# Age                           : 0

# %% [markdown]
# # Extraer informacion

# %%
# Ruta al archivo CSV en tu Google Drive
file_path = '/content/drive/MyDrive/scrap/texto_extraido.csv'
# Realiza una solicitud HTTP GET a la URL
response = requests.get(url)
# Extrae el contenido HTML de la respuesta
content = response.text
# Crea un objeto BeautifulSoup para analizar el contenido HTML
soup = BeautifulSoup(content, 'lxml')

from datetime import datetime


# Encuentra titulos, fechas ,secciones de las Ultimas noticias.
# para esto es necesario inspeccionar la pagina y obtener las partes requeridas
t_encabezado = soup.find('h2', class_='mod-title')
news_titles = soup.find_all('h2', class_='news-title')
news_dates = soup.find_all('time', class_='news-date')
news_sections = soup.find_all('span', class_='news-section')

# Obtiene el texto del encabezado
texto_h2 = t_encabezado.text
print(f"{'---'*20}\n{texto_h2}\n{'---'*20}\n")


# Abrir el archivo CSV para escribir la cabecera si es la primera iteración
with open(file_path, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Fecha', 'Seccion', 'Noticia', 'URL', 'Sinopsis', 'autor'])

# iterar entre las variables anteriores
for i, (news_date, news_section, news_title) in enumerate(zip(news_dates, news_sections, news_titles), start=1):

    # Muestra el contenido del atributo datetime de <time> (fecha)
    date_text = news_date['datetime']

    # Muestra el texto de <span> (seccion)
    section_text = news_section.get_text(strip=True)
    cleaned_text = ' '.join(section_text.split())
    #muestra el numero de iteraciones
    print(f"Numero Noticia {i} ")
    print(f"{'***'*20}\nSección: {cleaned_text}")

    # Extraer el enlace de redireccion q hay dentro del titulo

    # Encuentra el elemento <a> dentro del elemento h2 actual
    link_element = news_title.find('a')
    # Obtiene el enlace (href) y el texto del elemento <a>
    link_href = link_element.get('href')
    #muestra el texto de titulo de la noticia
    link_text = link_element.get_text(strip=True)

    #unir la url con el link del titulo de la noticia
    full_url = urljoin(url, link_href)

    #muestra resultados
    print(f"Noticia: {link_text}")
    print(f"Fecha: {date_text}")
    print(f"URL: {full_url}\n")

    #obtener el nombre autor q esta dentro del link de cada noticia
    # Realiza una solicitud HTTP a la URL completa
    linked_page_response = requests.get(full_url)

    # Crea un objeto BeautifulSoup para analizar el contenido de la página vinculada
    linked_page_soup = BeautifulSoup(linked_page_response.content, 'lxml')

    # Encuentra autores dentro de la pagina
    linked_page_content = linked_page_soup.find('p', class_='news-author')
    #linked_page_content_text = linked_page_content.get_text(strip=True).replace('por', '')

    # Imprime el contenido de la página vinculada
    print(f"Contenido del URL de la noticia:\n{linked_page_content.get_text(strip=True)}\n{'***' * 20}\n")

    #extra mostra primer parrafo de la noticia
    parrafo = linked_page_soup.find('div', class_='news-excerpt')

    # Imprime el contenido de la página vinculada
    print(f"{'▒▒▒'*20 }\n\tSinopsis:\n{parrafo.get_text(strip=True)}\n\n{'▒▒▒'* 20}\n\n")

    formatted_date = date_text.replace("T", " ")

# Convertir la cadena a un objeto datetime

    fecha_objeto = datetime.strptime(date_text, "%Y-%d-%mT%H:%M")


# Formatear la fecha y hora en otro formato ISO 8601
    fecha_iso8601_otro_formato = fecha_objeto.strftime("%Y-%m-%dT%H:%M:%S")
   # Escribe los datos en el archivo CSV
    with open(file_path, 'a', newline='') as file:
     writer = csv.writer(file)
     writer.writerow([fecha_objeto, cleaned_text, link_text, full_url, parrafo.get_text(strip=True), linked_page_content.get_text(strip=True)[4:]])
# Out:
# ------------------------------------------------------------
# Últimas noticias de Jalisco, Guadalajara, México y el Mundo
# ------------------------------------------------------------
#
# Numero Noticia 1
# ************************************************************
# Sección: Jalisco
# Noticia: Jalisco reporta 4 sismos este domingo
# Fecha: 2024-12-05T11:53
# URL: https://www.informador.mx/jalisco/Temblor-HOY-Jalisco-reporta-4-sismos-este-domingo-20240512-0061.html
#
# Contenido del URL de la noticia:
# Por:SUN .
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Diversos sismos se registraron durante la madrugada en nuestro estado, sin reportarse afectaciones
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 2
# ************************************************************
# Sección: Deportes
# Noticia: Real Madrid festeja su título 36 de LaLiga
# Fecha: 2024-12-05T11:49
# URL: https://www.informador.mx/deportes/Real-Madrid-festeja-su-titulo-36-de-LaLiga-20240512-0062.html
#
# Contenido del URL de la noticia:
# Por:SUN .
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# “Los merengues” recibieron el trofeo de su trigésimo sexta Liga, de manos del presidente de la Real Federación Española de Futbol (RFEF)
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 3
# ************************************************************
# Sección: Entretenimiento
# Noticia: ¿De qué trata y dónde ver Blue Lock, el anime deportivo del momento?
# Fecha: 2024-12-05T11:43
# URL: https://www.informador.mx/entretenimiento/Blue-Lock-De-que-trata-y-donde-ver-el-anime-deportivo-del-momento-20240512-0059.html
#
# Contenido del URL de la noticia:
# Por:Brenda Barragán
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Blue Lock es el anime que se está haciendo viral por su historia original
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 4
# ************************************************************
# Sección: México
# Noticia: SEP modifica horario escolar en estos estados por onda de calor
# Fecha: 2024-12-05T11:35
# URL: https://www.informador.mx/mexico/Temporada-de-calor-SEP-modifica-horario-escolar-en-estos-estados-por-onda-de-calor-20240512-0060.html
#
# Contenido del URL de la noticia:
# Por:SUN .
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Las autoridades han llamado a la población a evitar la exposición prolongada al sol
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 5
# ************************************************************
# Sección: Jalisco
# Noticia: Apagones en Chapala causan escasez de agua en el AMG
# Fecha: 2024-12-05T11:20
# URL: https://www.informador.mx/jalisco/Apagones-en-Chapala-causan-escasez-de-agua-en-el-AMG-20240512-0058.html
#
# Contenido del URL de la noticia:
# Por:Jessica Padilla
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# El gobernador reconoció las fallas en la estabilización del sistema de distribución de agua en el Área Metropolitana de Guadalajara (AMG)
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 6
# ************************************************************
# Sección: Entretenimiento
# Noticia: Esta es la fecha de estreno de "Blue Lock: Episode Nagi" la película de anime viral del momento (VIDEO)
# Fecha: 2024-12-05T11:17
# URL: https://www.informador.mx/entretenimiento/Blue-Lock-Episode-Nagi-Esta-es-la-fecha-de-estreno-de-la-pelicula-de-anime-viral-del-momento-VIDEO-20240512-0057.html
#
# Contenido del URL de la noticia:
# Por:Brenda Barragán
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Blue Lock: Episode Nagi está volviendo locos a todos en las redes sociales
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 7
# ************************************************************
# Sección: México
# Noticia: ¿Suspenderán clases por el calor? Esto responde SEP
# Fecha: 2024-12-05T10:44
# URL: https://www.informador.mx/mexico/Suspenderan-clases-en-Mexico-por-el-calor-Esto-responde-la-SEP-20240512-0055.html
#
# Contenido del URL de la noticia:
# Por:El Informador
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Debido a las afectaciones por las altas temperaturas, la SEP tomará medidas para proteger a los alumnos de educación básica en México
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 8
# ************************************************************
# Sección: Deportes
# Noticia: Conmebol reprograma partidos de Libertadores y Sudamericana por inundaciones en Brasil
# Fecha: 2024-12-05T10:39
# URL: https://www.informador.mx/deportes/Brasil-Conmebol-reprograma-partidos-de-Libertadores-y-Sudamericana-por-inundaciones-20240512-0056.html
#
# Contenido del URL de la noticia:
# Por:EFE
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Dirección de Competiciones y Operaciones de la Conmebol, confirmó que el partido de la Libertadores entre el club Huachipato y el brasileño Gremio finalmente se disputará el 4 de junio
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 9
# ************************************************************
# Sección: Entretenimiento
# Noticia: Un fuerte sismo y lluvia predice Mhoni Vidente para este día especial de mayo
# Fecha: 2024-12-05T10:30
# URL: https://www.informador.mx/entretenimiento/Mhoni-Vidente-Predice-un-fuerte-sismo-y-lluvia-para-este-dia-de-mayo-20240512-0050.html
#
# Contenido del URL de la noticia:
# Por:Brenda Barragán
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Atento que según Mhoni Vidente falta poco para ser víctima de la tempestuosa naturaleza en México
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 10
# ************************************************************
# Sección: Estilo
# Noticia: ¿Cuáles son los tipos de dolor de cabeza que le dan más a hombres y a mujeres?
# Fecha: 2024-12-05T10:12
# URL: https://www.informador.mx/estilo/Salud-2024-Cuales-son-los-tipos-de-dolor-de-cabeza-que-le-dan-mas-a-hombres-y-a-mujeres-20240509-0134.html
#
# Contenido del URL de la noticia:
# Por:Óscar Ernesto Álvarez Gutiérrez
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Los dolores de cabeza son comunes y en casos específicos pueden ser incapacitantes, pero ¿Cómo son? ¿Qué los produce? ¿Afectan más a hombres que a mujeres?
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 11
# ************************************************************
# Sección: Entretenimiento
# Noticia: La recomendación de hoy en la cartelera de cine es “El Planeta de los Simios: Nuevo Reino”
# Fecha: 2024-12-05T10:00
# URL: https://www.informador.mx/entretenimiento/El-Planeta-de-los-Simios-Nuevo-Reino-La-recomendacion-de-hoy-en-la-cartelera-de-cine-es-El-Planeta-de-los-Simios-Nuevo-Reino-20240511-0106.html
#
# Contenido del URL de la noticia:
# Por:Xochitl Martínez
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Uno de los estrenos de cine de la semana más esperado esEl Planeta de los Simios: Nuevo Reino, que ya se puede ver en las salas de cine de la ciudad
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 12
# ************************************************************
# Sección: México
# Noticia: Un sismo de magnitud 6.2 sacude Chiapas
# Fecha: 2024-12-05T09:59
# URL: https://www.informador.mx/mexico/Temblor-HOY-Un-sismo-de-magnitud-6.2-sacude-Chiapas-20240512-0054.html
#
# Contenido del URL de la noticia:
# Por:SUN .
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# El sismo también se sintió en países fronterizos como Guatemala y El Salvador
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 13
# ************************************************************
# Sección: Jalisco
# Noticia: Reportan falta de agua en el AMG
# Fecha: 2024-12-05T09:52
# URL: https://www.informador.mx/jalisco/Calor-HOY-Reportan-falta-de-agua-en-el-AMG-20240512-0053.html
#
# Contenido del URL de la noticia:
# Por:Jessica Padilla
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Distintas colonias de Guadalajara llevan padeciendo por la falta de agua durante más de tres días, en plena temporada de calor
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 14
# ************************************************************
# Sección: Internacional
# Noticia: Rusia tomó otras cuatro localidades en la región de Járkov en Ucrania
# Fecha: 2024-12-05T09:23
# URL: https://www.informador.mx/internacional/Rusia-tomo-otras-cuatro-localidades-en-la-region-de-Jarkov-en-Ucrania-20240512-0052.html
#
# Contenido del URL de la noticia:
# Por:EFE
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Se trata de los pueblos de Gatishe, Krasne, Morojovets y Olinykove, en la frontera con Rusia
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 15
# ************************************************************
# Sección: Estilo
# Noticia: ¿Cómo saber que un jitomate está "bueno"?
# Fecha: 2024-12-05T09:12
# URL: https://www.informador.mx/estilo/Como-saber-que-un-jitomate-esta-bueno-20240508-0153.html
#
# Contenido del URL de la noticia:
# Por:Óscar Ernesto Álvarez Gutiérrez
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Los jitomates más maduros (no podridos ni en malas condiciones) contienen más licopeno
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 16
# ************************************************************
# Sección: Estilo
# Noticia: ¿Beber agua durante o después de una comida altera la digestión?
# Fecha: 2024-12-05T09:03
# URL: https://www.informador.mx/estilo/Alimentacion-Beber-agua-durante-o-despues-de-una-comida-altera-la-digestion-20240509-0140.html
#
# Contenido del URL de la noticia:
# Por:El Informador
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Existe la creencia de que beber agua mientras se come, hay una alteración en el proceso de la digestión, aquí te decimos qué ocurre
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 17
# ************************************************************
# Sección: Internacional
# Noticia: Brasil: Van 144 muertos por fuertes lluvias en el sur del país
# Fecha: 2024-12-05T09:00
# URL: https://www.informador.mx/internacional/Brasil-Van-144-muertos-por-fuertes-lluvias-en-el-sur-del-pais-20240512-0051.html
#
# Contenido del URL de la noticia:
# Por:EFE
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# 125 personas continúan desaparecidas
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 18
# ************************************************************
# Sección: Estilo
# Noticia: Así puedes ser feliz en el trabajo, de acuerdo con Harvard
# Fecha: 2024-12-05T08:56
# URL: https://www.informador.mx/estilo/Asi-puedes-ser-feliz-en-el-trabajo-de-acuerdo-con-Harvard-20240510-0059.html
#
# Contenido del URL de la noticia:
# Por:SUN .
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# ¿Te sientes infeliz, agotado y desganado en tu empleo? Puedes cambiarlo siguiendo estos consejos de expertos
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 19
# ************************************************************
# Sección: Tecnología
# Noticia: WhatsApp: ¿qué es el modo piña y cómo lo puedes descargar?
# Fecha: 2024-12-05T08:38
# URL: https://www.informador.mx/tecnologia/WhatsApp-que-es-el-modo-pina-y-como-lo-puedes-descargar-20240508-0136.html
#
# Contenido del URL de la noticia:
# Por:El Informador
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# Activar el “modo piña” en tu aplicación de WhatsApp es fácil y sencillo, aquí te decimos cómo acceder a esta divertida opción
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#
#
# Numero Noticia 20
# ************************************************************
# Sección: Tecnología
# Noticia: Claves para reducir el riesgo de padecer cáncer de mama
# Fecha: 2024-12-05T08:24
# URL: https://www.informador.mx/tecnologia/Claves-para-reducir-el-riesgo-de-padecer-cancer-de-mama-20240508-0115.html
#
# Contenido del URL de la noticia:
# Por:NotiPress .
# ************************************************************
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
# 	Sinopsis:
# El cáncer de mama es una de las principales causas de muerte en México; así puedes reducir el riesgo de padecerlo
#
# ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
